# %% [markdown]
# # Load Modules

# %%
import os
import sys

import copy

import pickle

import numpy as np

from ase.visualize import view

# %% [markdown]
# # Load Data

# %%
with open("../slab_df.pickle", "rb") as fle:
    df = pickle.load(fle)

# %% [markdown]
# # Prepare systems

# %%
master_job_list = []

path_list = []
for i_cnt, row_i in df.iterrows():

    atoms = row_i["atoms"]

    elem_list_i = list(set(atoms.get_chemical_symbols()))
    try:
        elem_list_i.remove("C")
        metal_elem_i = elem_list_i[0]
    except:
        pass

    assert len(elem_list_i) == 1, "More than 1 non-C element!"

    metal_ind_list = []
    for atom in atoms:
        if atom.symbol == metal_elem_i:
            metal_ind_list.append(atom.index)

    support_atoms = atoms[metal_ind_list]
    z_positions = support_atoms.get_positions()[:,2]
    z_min = z_positions.min()
    z_max = z_positions.max()

    graphene_z_pos_list = np.linspace(z_max + 1., z_max + 6., num=30, endpoint=True)
    for graph_z_j in graphene_z_pos_list:
        atoms_j = copy.deepcopy(atoms)
        for atom in atoms_j:
            if atom.symbol == "C":
                atom.position[2] = graph_z_j


        job_dict_i = row_i.to_dict()
    
        job_dict_i["graphene_pos_above_support"] = graph_z_j - z_max
        job_dict_i["atoms_new"] = atoms_j
        job_dict_i["job_type"] = "opt_z_spacing"

        path_i = "/".join([
            str(job_dict_i.get("job_type", "nan")),
            str(job_dict_i.get("element", "nan")),
            str(job_dict_i.get("crystal_structure", "nan")),
            str(job_dict_i.get("facet", "nan")),
            '{:.5f}'.format(
                round(job_dict_i.get("graphene_pos_above_support", "nan"), 5)
                ),
            ])

        master_job_list.append(
            {
                "properties": job_dict_i,
                "path": path_i,
                }
            )

# %%
master_job_list
# Out:
# [{'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.0,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/1.00000'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.1724137931034484,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/1.17241'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.3448275862068968,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/1.34483'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.5172413793103452,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/1.51724'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.6896551724137936,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/1.68966'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.862068965517242,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/1.86207'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 2.0344827586206904,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/2.03448'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 2.206896551724139,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/2.20690'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 2.3793103448275836,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/2.37931'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 2.551724137931032,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/2.55172'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 2.7241379310344804,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/2.72414'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 2.896551724137929,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/2.89655'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 3.0689655172413772,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/3.06897'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 3.2413793103448256,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/3.24138'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 3.413793103448274,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/3.41379'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 3.586206896551726,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/3.58621'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 3.758620689655171,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/3.75862'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 3.9310344827586157,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/3.93103'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 4.103448275862068,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/4.10345'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 4.2758620689655125,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/4.27586'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 4.448275862068964,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/4.44828'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 4.620689655172409,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/4.62069'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 4.793103448275861,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/4.79310'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 4.965517241379306,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/4.96552'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 5.137931034482758,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/5.13793'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 5.310344827586203,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/5.31034'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 5.482758620689655,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/5.48276'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 5.6551724137931,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/5.65517'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet': '001',
#    'atoms': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 5.827586206896552,
#    'atoms_new': Atoms(symbols='C2Co6', pbc=True, cell=[[-1.244054999999999, -2.154766467410099, -3.0470559474265206e-16], [-2.48811, 0.0, -1.5235279737132603e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/Co/hcp/001/5.82759'},
#  {'properties': {'crystal_structure': 'hcp',
#    'element': 'Co',
#    'facet':

#    'atoms_new': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/211/4.44828'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '211',
#    'atoms': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 4.620689655172413,
#    'atoms_new': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/211/4.62069'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '211',
#    'atoms': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 4.793103448275861,
#    'atoms_new': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/211/4.79310'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '211',
#    'atoms': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 4.96551724137931,
#    'atoms_new': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/211/4.96552'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '211',
#    'atoms': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 5.137931034482758,
#    'atoms_new': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/211/5.13793'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '211',
#    'atoms': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 5.310344827586206,
#    'atoms_new': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/211/5.31034'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '211',
#    'atoms': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 5.482758620689655,
#    'atoms_new': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/211/5.48276'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '211',
#    'atoms': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 5.655172413793103,
#    'atoms_new': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/211/5.65517'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '211',
#    'atoms': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 5.827586206896552,
#    'atoms_new': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/211/5.82759'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '211',
#    'atoms': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 6.0,
#    'atoms_new': Atoms(symbols='C120W104', pbc=True, cell=[[-15.656464200773996, 6.97279063055417, -7.560901929643141e-16], [7.116574636715448, 17.431976576385424, 9.422438812569301e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/211/6.00000'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '321',
#    'atoms': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.0,
#    'atoms_new': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/321/1.00000'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '321',
#    'atoms': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.1724137931034484,
#    'atoms_new': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/321/1.17241'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '321',
#    'atoms': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.3448275862068968,
#    'atoms_new': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/321/1.34483'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '321',
#    'atoms': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.5172413793103452,
#    'atoms_new': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/321/1.51724'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '321',
#    'atoms': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.6896551724137936,
#    'atoms_new': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/321/1.68966'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '321',
#    'atoms': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 1.862068965517242,
#    'atoms_new': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/321/1.86207'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '321',
#    'atoms': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 2.0344827586206904,
#    'atoms_new': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/321/2.03448'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '321',
#    'atoms': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 2.206896551724139,
#    'atoms_new': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/321/2.20690'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '321',
#    'atoms': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 2.379310344827587,
#    'atoms_new': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/321/2.37931'},
#  {'properties': {'crystal_structure': 'bcc',
#    'element': 'W',
#    'facet': '321',
#    'atoms': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'graphene_pos_above_support': 2.5517241379310356,
#    'atoms_new': Atoms(symbols='C98W56', pbc=True, cell=[[8.051485095106699, 11.29721200522735, 6.910294618304573e-16], [18.115841463990073, -7.5314746701515665, 9.77263236920014e-16], [0.0, 0.0, 50.0]]),
#    'job_type': 'opt_z_spacing'},
#   'path': 'opt_z_spacing/W/bcc/321/2.55172'},
#  ...]

# %%
# atoms_list = []
# for i in master_job_list:
# #     print(i["path"])
#     atoms_list.append(i['properties']["atoms_new"])

# %%
# path_i = "/".join([
#     str(job_dict_i.get("job_type", "nan")),
#     str(job_dict_i.get("element", "nan")),
#     str(job_dict_i.get("crystal_structure", "nan")),
#     str(job_dict_i.get("facet", "nan")),
#     '{:.5f}'.format(round(job_dict_i.get("graphene_pos_above_support", "nan"), 5)),
#     ])

# print(path_i)

# %%
# # round(job_dict_i.get("graphene_pos_above_support", "nan"), 5)
# # round(2.23, 4)
# # print('${:.2f}'.format(
# #     job_dict_i.get("graphene_pos_above_support"
# # #     round(job_dict_i.get("graphene_pos_above_support", "nan"), 5)
# #     )


# print('{:.4f}'.format(
#     round(job_dict_i.get("graphene_pos_above_support", "nan"), 5)
#         )
#     )

# %%
# elem_list_i = list(set(atoms.get_chemical_symbols()))

# try:
#     elem_list_i.remove("C")
#     metal_elem = elem_list_i[0]
# except:
#     pass

# assert len(elem_list_i) == 1, "More than 1 non-C element!"

# %%
# atoms.get_cell()[-1]

# %%
# atoms_j = copy.deepcopy(atoms)
# for atom in atoms_j:
#     if atom.symbol == "C":
#         atom.position[2] = graph_z_j

# %%
# 27.157 - 24.857

# 27.157 - 24.857

# 29.957 - 24.857

# %%
# view(atoms[metal_ind_list])
