# %% [markdown]
# # Finding the Optmimal Lattice Constants for Bulk Support Materials
# ***
# Notes:
#
#   This will break when I put in the data that also has a c lattice constant.
#
#   Probably just make two plots (one for only a and one for both a and c lattice constants).
#
# ***

# %% [markdown]
# # Notebook Setup

# %% [markdown]
# ## Import Modules

# %%
import os
import sys

import numpy as np
import pandas as pd

from scipy.interpolate import interp1d

import plotly.plotly as py
import plotly.graph_objs as go

import pickle

# %% [markdown]
# ## Script Inputs

# %%
groupby_cols = [
    "support_metal",
    "crystal_structure",
    "spinpol",
    ]

prop_name_list = [
    "support_metal",
    "crystal_structure",
    "spinpol",
    ]
# support_metal




# smart_format_dict = [
# 
#     [
#         {"support_metal": "Ni"},
#         {"color2": "red"},
#         ],

#     [
#         {"support_metal": "Rh"},
#         {"color2": "blue"},
#         ],

#     [
#         {"support_metal": "Co"},
#         {"color2": "black"},
#         ],

#     [
#         {"support_metal": "Ru"},
#         {"color2": "green"},
#         ],

#     [
#         {"support_metal": "Mo"},
#         {"color2": "orange"},
#         ],

#     [
#         {"support_metal": "W"},
#         {"color2": "grey"},
#         ],

#     ]

system_color_dict = {
    "Ni": "red",
    "Rh": "blue",
    "Co": "black",
    "Ru": "green",
    "Mo": "orange",
    "W": "grey",
    }

# %% [markdown]
# ## Load Data

# %%
df_dir = os.path.join(
    ".",
    "job_dataframe_bulk_opt_ni_co_mo_01.pickle")
with open(df_dir, "rb") as fle:
    df_m_ni_co_mo_1 = pickle.load(fle, encoding="latin1")

df_dir = os.path.join(
    ".",
    "job_dataframe_bulk_opt_ni_co_mo_02.pickle")
with open(df_dir, "rb") as fle:
    df_m_ni_co_mo_2 = pickle.load(fle, encoding="latin1")

df_dir = os.path.join(
    ".",
    "job_dataframe_bulk_opt_ru_rh_w_01.pickle")
with open(df_dir, "rb") as fle:
    df_m_ru_rh_w_1 = pickle.load(fle, encoding="latin1")

frames = [
    df_m_ni_co_mo_1,
    df_m_ni_co_mo_2,
    df_m_ru_rh_w_1,
    ]

df_m = pd.concat(frames)

# Getting rid of duplicate columns
df_m = df_m.loc[:,~df_m.columns.duplicated()]
df_m = df_m.replace(np.nan, 'nan', regex=True)
df_m = df_m[df_m["elec_energy"] != "nan"]

# Selecting HCP materials
df_m = df_m[df_m["c"] == "nan"]
# df_m = df_m[df_m["c"] != "nan"]

# df_m = df_m[df_m["support_metal"] == "Mo"]
# df_m = df_m[df_m["spinpol"] == False]

# %% [markdown]
# # Processing Data

# %% [markdown]
# ## Process DFT Jobs

# %%
data = []
groupby = df_m.groupby(groupby_cols)
for name_i, group_i in groupby:
    group_i = group_i.sort_values(by=["a"])


    group_i["elec_energy_norm"] = 0. + \
        group_i["elec_energy"] - \
        group_i["elec_energy"].min()

    a_list = group_i["a"].tolist()
    energy_list = group_i["elec_energy_norm"].tolist()

    name_i = ""
    for prop_i in prop_name_list:   
        name_i += str(group_i[prop_i].tolist()[0]) + "_"

    name_i = name_i[0:-1]

    color_i = None
    if len(list(set(group_i["support_metal"].tolist()))) == 1:
        support_metal = list(set(group_i["support_metal"].tolist()))[0]
        color_i = system_color_dict[support_metal]

    if len(list(set(group_i["spinpol"].tolist()))) == 1:
        spinpol = list(set(group_i["spinpol"].tolist()))[0]
        
        if spinpol is True:
            shape_i = "circle"
        elif spinpol is False:
            shape_i = "triangle-up"

    # ###################################################
    # ###################################################
    # ###################################################

    no_c_latt_const = False
    c_col = list(set(group_i["c"].tolist()))
    if len(c_col) == 1 and "nan" in c_col:
        no_c_latt_const = True

    a_list = group_i["a"].tolist()
    energy_list = group_i["elec_energy_norm"].tolist()

    name_i = ""
    for prop_i in prop_name_list:   
        name_i += str(group_i[prop_i].tolist()[0]) + "_"

    name_i = name_i[0:-1]
    data.append(go.Scatter(
        x=a_list,
        y=energy_list,
        mode='markers',
        name=name_i,
        marker=dict(
            size=8,
            color=color_i,
            symbol=shape_i,
            )
        ))

    # ###################################################
    # ###################################################
    # ###################################################

    x_axis_interp = np.linspace(
        np.array(a_list).min(),
        np.array(a_list).max(),
        1000,
        )
    interp_out = interp1d(
        a_list,
        energy_list,
        kind="cubic",
        )(x_axis_interp)

    interp_i = go.Scatter(
        x=x_axis_interp,
        y=interp_out,
        mode='lines',
        )

    data.append(interp_i)

    min_ind = np.argmin(interp_out)
    min_i = go.Scatter(
        x=[x_axis_interp[min_ind]],
        y=[interp_out[min_ind]],
        mode='markers',
        marker=dict(
            size=10,
            color="red",
            symbol="star",
            )
        )

    data.append(min_i)

# %%
group_i
# Out:
#                                                     Job        a    c  \
# 3280  <dft_job_automat.job_setup.Job object at 0x7fd...  3.10190  nan
# 3282  <dft_job_automat.job_setup.Job object at 0x7fd...  3.10514  nan
# 3284  <dft_job_automat.job_setup.Job object at 0x7fd...  3.10839  nan
# 3286  <dft_job_automat.job_setup.Job object at 0x7fd...  3.11164  nan
# 3288  <dft_job_automat.job_setup.Job object at 0x7fd...  3.11488  nan
# 3290  <dft_job_automat.job_setup.Job object at 0x7fd...  3.11813  nan
# 3292  <dft_job_automat.job_setup.Job object at 0x7fd...  3.12137  nan
# 3294  <dft_job_automat.job_setup.Job object at 0x7fd...  3.12462  nan
# 3296  <dft_job_automat.job_setup.Job object at 0x7fd...  3.12787  nan
# 3298  <dft_job_automat.job_setup.Job object at 0x7fd...  3.13111  nan
# 3300  <dft_job_automat.job_setup.Job object at 0x7fd...  3.13436  nan
# 3302  <dft_job_automat.job_setup.Job object at 0x7fd...  3.13761  nan
# 3304  <dft_job_automat.job_setup.Job object at 0x7fd...  3.14085  nan
# 3306  <dft_job_automat.job_setup.Job object at 0x7fd...  3.14410  nan
# 3308  <dft_job_automat.job_setup.Job object at 0x7fd...  3.14735  nan
# 3310  <dft_job_automat.job_setup.Job object at 0x7fd...  3.15059  nan
# 3312  <dft_job_automat.job_setup.Job object at 0x7fd...  3.15384  nan
# 3314  <dft_job_automat.job_setup.Job object at 0x7fd...  3.15708  nan
# 3316  <dft_job_automat.job_setup.Job object at 0x7fd...  3.16033  nan
# 3318  <dft_job_automat.job_setup.Job object at 0x7fd...  3.16358  nan
# 3320  <dft_job_automat.job_setup.Job object at 0x7fd...  3.16682  nan
# 3322  <dft_job_automat.job_setup.Job object at 0x7fd...  3.17007  nan
# 3324  <dft_job_automat.job_setup.Job object at 0x7fd...  3.17332  nan
# 3326  <dft_job_automat.job_setup.Job object at 0x7fd...  3.17656  nan
# 3328  <dft_job_automat.job_setup.Job object at 0x7fd...  3.17981  nan
# 3330  <dft_job_automat.job_setup.Job object at 0x7fd...  3.18305  nan
# 3332  <dft_job_automat.job_setup.Job object at 0x7fd...  3.18630  nan
# 3334  <dft_job_automat.job_setup.Job object at 0x7fd...  3.18955  nan
# 3336  <dft_job_automat.job_setup.Job object at 0x7fd...  3.19279  nan
# 3338  <dft_job_automat.job_setup.Job object at 0x7fd...  3.19604  nan
# 3340  <dft_job_automat.job_setup.Job object at 0x7fd...  3.19929  nan
# 3342  <dft_job_automat.job_setup.Job object at 0x7fd...  3.20253  nan
# 3344  <dft_job_automat.job_setup.Job object at 0x7fd...  3.20578  nan
# 3346  <dft_job_automat.job_setup.Job object at 0x7fd...  3.20903  nan
# 3348  <dft_job_automat.job_setup.Job object at 0x7fd...  3.21227  nan
# 3350  <dft_job_automat.job_setup.Job object at 0x7fd...  3.21552  nan
# 3352  <dft_job_automat.job_setup.Job object at 0x7fd...  3.21876  nan
# 3354  <dft_job_automat.job_setup.Job object at 0x7fd...  3.22201  nan
# 3356  <dft_job_automat.job_setup.Job object at 0x7fd...  3.22526  nan
# 3358  <dft_job_automat.job_setup.Job object at 0x7fd...  3.22850  nan
#
#      crystal_structure  max_revision                            path  \
# 3280               bcc             1   data/W/bcc/True/3.1019-nan/_1
# 3282               bcc             1  data/W/bcc/True/3.10514-nan/_1
# 3284               bcc             1  data/W/bcc/True/3.10839-nan/_1
# 3286               bcc             1  data/W/bcc/True/3.11164-nan/_1
# 3288               bcc             1  data/W/bcc/True/3.11488-nan/_1
# 3290               bcc             1  data/W/bcc/True/3.11813-nan/_1
# 3292               bcc             1  data/W/bcc/True/3.12137-nan/_1
# 3294               bcc             1  data/W/bcc/True/3.12462-nan/_1
# 3296               bcc             1  data/W/bcc/True/3.12787-nan/_1
# 3298               bcc             1  data/W/bcc/True/3.13111-nan/_1
# 3300               bcc             1  data/W/bcc/True/3.13436-nan/_1
# 3302               bcc             1  data/W/bcc/True/3.13761-nan/_1
# 3304               bcc             1  data/W/bcc/True/3.14085-nan/_1
# 3306               bcc             1   data/W/bcc/True/3.1441-nan/_1
# 3308               bcc             1  data/W/bcc/True/3.14735-nan/_1
# 3310               bcc             1  data/W/bcc/True/3.15059-nan/_1
# 3312               bcc             1  data/W/bcc/True/3.15384-nan/_1
# 3314               bcc             1  data/W/bcc/True/3.15708-nan/_1
# 3316               bcc             1  data/W/bcc/True/3.16033-nan/_1
# 3318               bcc             1  data/W/bcc/True/3.16358-nan/_1
# 3320               bcc             1  data/W/bcc/True/3.16682-nan/_1
# 3322               bcc             1  data/W/bcc/True/3.17007-nan/_1
# 3324               bcc             1  data/W/bcc/True/3.17332-nan/_1
# 3326               bcc             1  data/W/bcc/True/3.17656-nan/_1
# 3328               bcc             1  data/W/bcc/True/3.17981-nan/_1
# 3330               bcc             1  data/W/bcc/True/3.18305-nan/_1
# 3332               bcc             1   data/W/bcc/True/3.1863-nan/_1
# 3334               bcc             1  data/W/bcc/True/3.18955-nan/_1
# 3336               bcc             1  data/W/bcc/True/3.19279-nan/_1
# 3338               bcc             1  data/W/bcc/True/3.19604-nan/_1
# 3340               bcc             1  data/W/bcc/True/3.19929-nan/_1
# 3342               bcc             1  data/W/bcc/True/3.20253-nan/_1
# 3344               bcc             1  data/W/bcc/True/3.20578-nan/_1
# 3346               bcc             1  data/W/bcc/True/3.20903-nan/_1
# 3348               bcc             1  data/W/bcc/True/3.21227-nan/_1
# 3350               bcc             1  data/W/bcc/True/3.21552-nan/_1
# 3352               bcc             1  data/W/bcc/True/3.21876-nan/_1
# 3354               bcc             1  data/W/bcc/True/3.22201-nan/_1
# 3356               bcc             1  data/W/bcc/True/3.22526-nan/_1
# 3358               bcc             1   data/W/bcc/True/3.2285-nan/_1
#
#       revision_number  spinpol support_metal elec_energy       ...         \
# 3280                1     True             W    -2183.56       ...
# 3282                1     True             W    -2183.57       ...
# 3284                1     True             W    -2183.58       ...
# 3286                1     True             W    -2183.59       ...
# 3288                1     True             W    -2183.59       ...
# 3290                1     True             W     -2183.6       ...
# 3292                1     True             W     -2183.6       ...
# 3294                1     True             W    -2183.61       ...
# 3296                1     True             W    -2183.61       ...
# 3298                1     True             W    -2183.62       ...
# 3300                1     True             W    -2183.62       ...
# 3302                1     True             W    -2183.63       ...
# 3304                1     True             W    -2183.63       ...
# 3306                1     True             W    -2183.63       ...
# 3308                1     True             W    -2183.64       ...
# 3310                1     True             W    -2183.64       ...
# 3312                1     True             W    -2183.64       ...
# 3314                1     True             W    -2183.65       ...
# 3316                1     True             W    -2183.65       ...
# 3318                1     True             W    -2183.65       ...
# 3320                1     True             W    -2183.65       ...
# 3322                1     True             W    -2183.65       ...
# 3324                1     True             W    -2183.65       ...
# 3326                1     True             W    -2183.65       ...
# 3328                1     True             W    -2183.65       ...
# 3330                1     True             W    -2183.65       ...
# 3332                1     True             W    -2183.65       ...
# 3334                1     True             W    -2183.65       ...
# 3336                1     True             W    -2183.65       ...
# 3338                1     True             W    -2183.65       ...
# 3340                1     True             W    -2183.64       ...
# 3342                1     True             W    -2183.64       ...
# 3344                1     True             W    -2183.64       ...
# 3346                1     True             W    -2183.64       ...
# 3348                1     True             W    -2183.64       ...
# 3350                1     True             W    -2183.63       ...
# 3352                1     True             W    -2183.63       ...
# 3354                1     True             W    -2183.63       ...
# 3356                1     True             W    -2183.62       ...
# 3358                1     True             W    -2183.62       ...
#
#      nbands noncollinear   outdir                output parflags  \
# 3280    -50        False  calcdir  {'removesave': True}      nan
# 3282    -50        False  calcdir  {'removesave': True}      nan
# 3284    -50        False  calcdir  {'removesave': True}      nan
# 3286    -50        False  calcdir  {'removesave': True}      nan
# 3288    -50        False  calcdir  {'removesave': True}      nan
# 3290    -50        False  calcdir  {'removesave': True}      nan
# 3292    -50        False  calcdir  {'removesave': True}      nan
# 3294    -50        False  calcdir  {'removesave': True}      nan
# 3296    -50        False  calcdir  {'removesave': True}      nan
# 3298    -50        False  calcdir  {'removesave': True}      nan
# 3300    -50        False  calcdir  {'removesave': True}      nan
# 3302    -50        False  calcdir  {'removesave': True}      nan
# 3304    -50        False  calcdir  {'removesave': True}      nan
# 3306    -50        False  calcdir  {'removesave': True}      nan
# 3308    -50        False  calcdir  {'removesave': True}      nan
# 3310    -50        False  calcdir  {'removesave': True}      nan
# 3312    -50        False  calcdir  {'removesave': True}      nan
# 3314    -50        False  calcdir  {'removesave': True}      nan
# 3316    -50        False  calcdir  {'removesave': True}      nan
# 3318    -50        False  calcdir  {'removesave': True}      nan
# 3320    -50        False  calcdir  {'removesave': True}      nan
# 3322    -50        False  calcdir  {'removesave': True}      nan
# 3324    -50        False  calcdir  {'removesave': True}      nan
# 3326    -50        False  calcdir  {'removesave': True}      nan
# 3328    -50        False  calcdir  {'removesave': True}      nan
# 3330    -50        False  calcdir  {'removesave': True}      nan
# 3332    -50        False  calcdir  {'removesave': True}      nan
# 3334    -50        False  calcdir  {'removesave': True}      nan
# 3336    -50        False  calcdir  {'removesave': True}      nan
# 3338    -50        False  calcdir  {'removesave': True}      nan
# 3340    -50        False  calcdir  {'removesave': True}      nan
# 3342    -50        False  calcdir  {'removesave': True}      nan
# 3344    -50        False  calcdir  {'removesave': True}      nan
# 3346    -50        False  calcdir  {'removesave': True}      nan
# 3348    -50        False  calcdir  {'removesave': True}      nan
# 3350    -50        False  calcdir  {'removesave': True}      nan
# 3352    -50        False  calcdir  {'removesave': True}      nan
# 3354    -50        False  calcdir  {'removesave': True}      nan
# 3356    -50        False  calcdir  {'removesave': True}      nan
# 3358    -50        False  calcdir  {'removesave': True}      nan
#
#      printensemble   pw  sigma        xc elec_energy_norm
# 3280          True  600  0.005  BEEF-vdW        0.0868074
# 3282          True  600  0.005  BEEF-vdW        0.0788863
# 3284          True  600  0.005  BEEF-vdW        0.0714582
# 3286          True  600  0.005  BEEF-vdW        0.0647498
# 3288          True  600  0.005  BEEF-vdW        0.0591978
# 3290          True  600  0.005  BEEF-vdW        0.0521086
# 3292          True  600  0.005  BEEF-vdW        0.0467013
# 3294          True  600  0.005  BEEF-vdW        0.0411867
# 3296          True  600  0.005  BEEF-vdW        0.0369948
# 3298          True  600  0.005  BEEF-vdW        0.0318404
# 3300          True  600  0.005  BEEF-vdW        0.0274581
# 3302          True  600  0.005  BEEF-vdW        0.0237845
# 3304          True  600  0.005  BEEF-vdW        0.0196849
# 3306          True  600  0.005  BEEF-vdW        0.0162384
# 3308          True  600  0.005  BEEF-vdW        0.0130017
# 3310          True  600  0.005  BEEF-vdW        0.0107482
# 3312          True  600  0.005  BEEF-vdW         0.008003
# 3314          True  600  0.005  BEEF-vdW       0.00589507
# 3316          True  600  0.005  BEEF-vdW       0.00389504
# 3318          True  600  0.005  BEEF-vdW       0.00321013
# 3320          True  600  0.005  BEEF-vdW       0.00211052
# 3322          True  600  0.005  BEEF-vdW       0.00131907
# 3324          True  600  0.005  BEEF-vdW      0.000325312
# 3326          True  600  0.005  BEEF-vdW      0.000351435
# 3328          True  600  0.005  BEEF-vdW      0.000537153
# 3330          True  600  0.005  BEEF-vdW                0
# 3332          True  600  0.005  BEEF-vdW       0.00125649
# 3334          True  600  0.005  BEEF-vdW       0.00175309
# 3336          True  600  0.005  BEEF-vdW       0.00320196
# 3338          True  600  0.005  BEEF-vdW       0.00349421
# 3340          True  600  0.005  BEEF-vdW       0.00595059
# 3342          True  600  0.005  BEEF-vdW        0.0077713
# 3344          True  600  0.005  BEEF-vdW        0.0103772
# 3346          True  600  0.005  BEEF-vdW        0.0123176
# 3348          True  600  0.005  BEEF-vdW        0.0155623
# 3350          True  600  0.005  BEEF-vdW        0.0182605
# 3352          True  600  0.005  BEEF-vdW        0.0217577
# 3354          True  600  0.005  BEEF-vdW        0.0250909
# 3356          True  600  0.005  BEEF-vdW        0.0292916
# 3358          True  600  0.005  BEEF-vdW        0.0321595
#
# [40 rows x 28 columns]

# %% [markdown]
# # Plotting

# %%
axes_lab_size = 12 * (4./3.)
tick_lab_size = 9 * (4./3.)

common_axis_dict = {

    # "range": y_axis_range,
    "zeroline": False,
    "showline": True,
    "mirror": 'ticks',
    "linecolor": 'black',
    "showgrid": False,

    "titlefont": dict(size=axes_lab_size),
    "tickfont": dict(
        size=tick_lab_size,
        ),
    "ticks": 'inside',
    "tick0": 0,
    "tickcolor": 'black',
    # "dtick": 0.25,
    "ticklen": 2,
    "tickwidth": 1,
    }

layout = {
    "title": "Lattice constant bulk optmization (Ni, Co, Mo)",
    "titlefont": go.layout.Titlefont(size=24),

    "xaxis": dict(
        common_axis_dict,
        **{
            "title": "a",
#             "range": x_range,
            },
        ),

    "yaxis": dict(
        common_axis_dict,
        **{
            "title": "Electronic Energy (eV)",
#             "range": y_range,
            },
        ),

    "font": dict(
        family='Arial',
        # size=18,
        color='black',
        ),

#     "width": 1.5 * 18.7 * 37.795275591,
#     "height": 18.7 * 37.795275591,

    "showlegend": True,

    "legend": dict(
        # x=0.,
        # y=1.8,
        font=dict(
            size=10,
            ),
        ),
    }

# %%
fig = dict(data=data, layout=layout)

py.iplot(fig, filename='__temp__/basic-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~flores12/479.embed" height="525px" width="100%"></iframe>

# %%
# x_axis_interp
# interp_out = interp1d(
#     a_list,
#     energy_list,
#     kind="cubic",
#     )(x_axis_interp)

# %%
# min_ind = np.argmin(interp_out)
# interp_out[min_ind]
# x_axis_interp[min_ind]

# %%
# group_i["elec_energy_norm"].min()

# row_min = group_i[group_i['elec_energy_norm'] == group_i['elec_energy_norm'].min()]

# row_min["elec_energy_norm"].iloc[0]
# row_min["a"].iloc[0]


# min_i = go.Scatter(
#     x=[row_min["a"].iloc[0]],
#     y=[row_min["elec_energy_norm"].iloc[0]],
# #     interp1d(
# #         a_list,
# #         energy_list,
# #         kind="cubic",
# #         )(x_axis_interp),

#     mode='markers',
#     )

# data.append(min_i)

# %%
# from scipy.interpolate import interp1d

# x = np.linspace(0, 10, num=11, endpoint=True)
# y = np.cos(-x**2/9.0)
# # f = interp1d(x, y)
# f2 = interp1d(x, y, kind='cubic')

# f2()

# y=np.interp(
#     x_axis_interp,
#     a_list,
#     energy_list,
#     )

# interp1d(a_list, energy_list, kind='cubic')(x_axis_interp)

# %%
#     if no_c_latt_const is False:
#         print("sKLfjaskfsdj")
#         groupby = group_i.groupby(["c"])
#         for name_j, group_j in groupby:            
#             a_list = group_j["a"].tolist()
#             energy_list = group_j["elec_energy_norm"].tolist()

#             name_i = ""
#             for prop_i in prop_name_list:   
#                 name_i += str(group_j[prop_i].tolist()[0]) + "_"

#             name_i = name_i[0:-1]
            
#             data.append(go.Scatter(
#                 x=a_list,
#                 y=energy_list,
#                 mode='markers',
#                 name=name_i,
#                 marker = dict(
#                     size = 8,
#                     color = color_i,
# #                     line = dict(
# #                         width = 2,
# #                         color = 'rgb(0, 0, 0)'
# #                         )
#                     )
#                 ))

# %%
# if len(list(set(group_i["spinpol"].tolist()))) == 1:
#     spinpol = list(set(group_i["spinpol"].tolist()))[0]

# %%
# no_c_latt_const = all(np.isnan(group_i["c"].tolist()))
# all(
# np.isnan(group_i["c"].tolist())
# )

# %%
# x_axis_interp = np.linspace(
#     np.array(a_list).min(),
#     np.array(a_list).max(),
#     300,
#     )

# np.interp(
#     x_axis_interp,
#     a_list,
#     energy_list,
#     )

# interp_i = go.Scatter(
#     x=x_axis_interp,
#     y=np.interp(
#         x_axis_interp,
#         a_list,
#         energy_list,
#         ),

#     mode='lines',

# #     name=name_i,
# #     marker = dict(
# #         size = 8,
# #         color = color_i,
# # #                     line = dict(
# # #                         width = 2,
# # #                         color = 'rgb(0, 0, 0)'
# # #                         )
# #         )

#     )

# # data.append(interp_i)

# %%
# c_col = list(set(group_i["c"].tolist()))
# if len(c_col) == 1 and "nan" in c_col:
#     tmp = 42

# %%
# df_m

# df_m = df_m.replace(np.nan, 'nan', regex=True)

# %%
# a_list = group_i["a"].tolist()

# # if "c" in list()
# # c_list = group_i["c"].tolist()

# energy_list = group_i["elec_energy"].tolist()

# no_c_latt_const = all(np.isnan(group_i["c"].tolist()))

# if no_c_latt_const is False:
#     groupby = df_m.groupby(["c"])
#     for name_j, group_j in groupby:
#         tmp = 42

# name_i = ""
# for prop_i in prop_name_list:   
#     name_i += str(group_i[prop_i].tolist()[0]) + "_"

# name_i = name_i[0:-1]

# %%
# if len(list(set(group_i["support_metal"].tolist()))) == 1:
#     support_metal = list(set(group_i["support_metal"].tolist()))[0]

# %%
# data_points = go.Scatter3d(
#     x=a_lst,
#     y=b_a_lst,
#     z=elec_energy_lst,
#     mode='markers',
  
#     marker=dict(
#         size=6,
# #         color=elec_energy_lst,                # set color to an array/list of desired values
#         color="grey",                # set color to an array/list of desired values
# #         colorscale='magma',   # choose a colorscale
#         colorscale='Blackbody',   # choose a colorscale
#         opacity=1.
#         )    
#     )

# fig = go.Figure(data=[data_points], layout=layout2)
# py.iplot(fig, filename=pl_dir + '/pl_latt_opt_data_points')
