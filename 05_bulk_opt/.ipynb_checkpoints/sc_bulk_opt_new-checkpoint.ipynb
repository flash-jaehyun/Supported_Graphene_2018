# %% [markdown]
# # Finding the Optmimal Lattice Constants for Bulk Support Materials
# ***
# Notes:
#
#   This will break when I put in the data that also has a c lattice constant.
#
#   Probably just make two plots (one for only a and one for both a and c lattice constants).
#
# ***

# %% [markdown]
# # Notebook Setup

# %% [markdown]
# ## Import Modules

# %%
import os
import sys

import numpy as np
import pandas as pd

from scipy.interpolate import interp1d

import plotly.plotly as py
import plotly.graph_objs as go

import pickle

# %% [markdown]
# ## Script Inputs

# %%
groupby_cols = [
    "support_metal",
    "crystal_structure",
    "spinpol",
    ]

prop_name_list = [
    "support_metal",
    "crystal_structure",
    "spinpol",
    ]
# support_metal




# smart_format_dict = [
# 
#     [
#         {"support_metal": "Ni"},
#         {"color2": "red"},
#         ],

#     [
#         {"support_metal": "Rh"},
#         {"color2": "blue"},
#         ],

#     [
#         {"support_metal": "Co"},
#         {"color2": "black"},
#         ],

#     [
#         {"support_metal": "Ru"},
#         {"color2": "green"},
#         ],

#     [
#         {"support_metal": "Mo"},
#         {"color2": "orange"},
#         ],

#     [
#         {"support_metal": "W"},
#         {"color2": "grey"},
#         ],

#     ]

system_color_dict = {
    "Ni": "red",
    "Rh": "blue",
    "Co": "black",
    "Ru": "green",
    "Mo": "orange",
    "W": "grey",
    }

# %% [markdown]
# ## Load Data

# %%
df_dir = os.path.join(
    ".",
    "job_dataframe_bulk_opt_ni_co_mo_01.pickle")
with open(df_dir, "rb") as fle:
    df_m_ni_co_mo_1 = pickle.load(fle, encoding="latin1")

df_dir = os.path.join(
    ".",
    "job_dataframe_bulk_opt_ni_co_mo_02.pickle")
with open(df_dir, "rb") as fle:
    df_m_ni_co_mo_2 = pickle.load(fle, encoding="latin1")

df_dir = os.path.join(
    ".",
    "job_dataframe_bulk_opt_ru_rh_w_01.pickle")
with open(df_dir, "rb") as fle:
    df_m_ru_rh_w_1 = pickle.load(fle, encoding="latin1")

frames = [
    df_m_ni_co_mo_1,
    df_m_ni_co_mo_2,
    df_m_ru_rh_w_1,
    ]

df_m = pd.concat(frames)

# Getting rid of duplicate columns
df_m = df_m.loc[:,~df_m.columns.duplicated()]
df_m = df_m.replace(np.nan, 'nan', regex=True)
df_m = df_m[df_m["elec_energy"] != "nan"]

# Selecting HCP materials
df_m = df_m[df_m["c"] == "nan"]
# df_m = df_m[df_m["c"] != "nan"]

# df_m = df_m[df_m["support_metal"] == "Mo"]
# df_m = df_m[df_m["spinpol"] == False]

# %% [markdown]
# # Processing Data

# %% [markdown]
# ## Process DFT Jobs

# %%
data = []
groupby = df_m.groupby(groupby_cols)
for name_i, group_i in groupby:
    group_i = group_i.sort_values(by=["a"])


    group_i["elec_energy_norm"] = 0. + \
        group_i["elec_energy"] - \
        group_i["elec_energy"].min()

    a_list = group_i["a"].tolist()
    energy_list = group_i["elec_energy_norm"].tolist()

    name_i = ""
    for prop_i in prop_name_list:   
        name_i += str(group_i[prop_i].tolist()[0]) + "_"

    name_i = name_i[0:-1]

    color_i = None
    if len(list(set(group_i["support_metal"].tolist()))) == 1:
        support_metal = list(set(group_i["support_metal"].tolist()))[0]
        color_i = system_color_dict[support_metal]

    if len(list(set(group_i["spinpol"].tolist()))) == 1:
        spinpol = list(set(group_i["spinpol"].tolist()))[0]
        
        if spinpol is True:
            shape_i = "circle"
        elif spinpol is False:
            shape_i = "triangle-up"

    # ###################################################
    # ###################################################
    # ###################################################

    no_c_latt_const = False
    c_col = list(set(group_i["c"].tolist()))
    if len(c_col) == 1 and "nan" in c_col:
        no_c_latt_const = True

    a_list = group_i["a"].tolist()
    energy_list = group_i["elec_energy_norm"].tolist()

    name_i = ""
    for prop_i in prop_name_list:   
        name_i += str(group_i[prop_i].tolist()[0]) + "_"

    name_i = name_i[0:-1]
    data.append(go.Scatter(
        x=a_list,
        y=energy_list,
        mode='markers',
        name=name_i,
        marker=dict(
            size=8,
            color=color_i,
            symbol=shape_i,
            )
        ))

    # ###################################################
    # ###################################################
    # ###################################################

    x_axis_interp = np.linspace(
        np.array(a_list).min(),
        np.array(a_list).max(),
        1000,
        )
    interp_out = interp1d(
        a_list,
        energy_list,
        kind="cubic",
        )(x_axis_interp)

    interp_i = go.Scatter(
        x=x_axis_interp,
        y=interp_out,
        mode='lines',
        )

    data.append(interp_i)

    min_ind = np.argmin(interp_out)
    min_i = go.Scatter(
        x=[x_axis_interp[min_ind]],
        y=[interp_out[min_ind]],
        mode='markers',
        marker=dict(
            size=10,
            color="red",
            symbol="star",
            )
        )

    data.append(min_i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-3a0037ff34d5> in <module>()
#      70         a_list,
#      71         energy_list,
# ---> 72         kind="cubic",
#      73         )(x_axis_interp)
#      74
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/scipy/interpolate/interpolate.py in __init__(***failed resolving arguments***)
#     533
#     534             self._spline = make_interp_spline(xx, yy, k=order,
# --> 535                                               check_finite=False)
#     536             if rewrite_nan:
#     537                 self._call = self.__class__._call_nan_spline
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/scipy/interpolate/_bsplines.py in make_interp_spline(x, y, k, t, bc_type, axis, check_finite)
#     775
#     776     if x.ndim != 1 or np.any(x[1:] <= x[:-1]):
# --> 777         raise ValueError("Expect x to be a 1-D sorted array_like.")
#     778     if k < 0:
#     779         raise ValueError("Expect non-negative k.")
#
# ValueError: Expect x to be a 1-D sorted array_like.

# %%
group_i
# Out:
#                                                     Job        a        c  \
# 61    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  3.86602
# 119   <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.27298
# 117   <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.25894
# 115   <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.24491
# 113   <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.23088
# 111   <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.21684
# 109   <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.20281
# 107   <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.18878
# 103   <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.16071
# 101   <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.14668
# 99    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.13265
# 97    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.11861
# 95    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.10458
# 93    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.09055
# 91    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.07652
# 105   <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.17475
# 87    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.04845
# 89    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.06248
# 63    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  3.88006
# 65    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  3.89409
# 67    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  3.90812
# 69    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  3.92216
# 73    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  3.95022
# 71    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  3.93619
# 77    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  3.97829
# 79    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  3.99232
# 81    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.00635
# 83    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.02039
# 85    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  4.03442
# 75    <dft_job_automat.job_setup.Job object at 0x7f2...  2.38174  3.96425
# ...                                                 ...      ...      ...
# 1837  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.11861
# 1839  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.13265
# 1841  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.14668
# 1843  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.16071
# 1845  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.17475
# 1859  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.27298
# 1849  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.20281
# 1851  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.21684
# 1853  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.23088
# 1855  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.24491
# 1857  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.25894
# 1835  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.10458
# 1847  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.18878
# 1833  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.09055
# 1819  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  3.99232
# 1829  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.06248
# 1827  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.04845
# 1825  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.03442
# 1823  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.02039
# 1821  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  4.00635
# 1817  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246  3.97829
# 1815  <dft_job_automat.job_setup.Job object at 0x7f2...  2.63246
# 1855                1    False            Co    -8150.19       ...
# 1857                1    False            Co    -8150.18       ...
# 1835                1    False            Co    -8150.35       ...
# 1847                1    False            Co    -8150.26       ...
# 1833                1    False            Co    -8150.36       ...
# 1819                1    False            Co    -8150.44       ...
# 1829                1    False            Co    -8150.38       ...
# 1827                1    False            Co     -8150.4       ...
# 1825                1    False            Co    -8150.41       ...
# 1823                1    False            Co    -8150.42       ...
# 1821                1    False            Co    -8150.43       ...
# 1817                1    False            Co    -8150.45       ...
# 1815                1    False            Co    -8150.46       ...
# 1813                1    False            Co    -8150.46       ...
# 1811                1    False            Co    -8150.47       ...
# 1809                1    False            Co    -8150.47       ...
# 1807                1    False            Co    -8150.48       ...
# 1801                1    False            Co     -8150.5       ...
# 1803                1    False            Co    -8150.49       ...
# 1831                1    False            Co    -8150.37       ...
# 1805                1    False            Co    -8150.48       ...
#
#      nbands noncollinear   outdir                output parflags  \
# 61      -50        False  calcdir  {'removesave': True}      nan
# 119     -50        False  calcdir  {'removesave': True}      nan
# 117     -50        False  calcdir  {'removesave': True}      nan
# 115     -50        False  calcdir  {'removesave': True}      nan
# 113     -50        False  calcdir  {'removesave': True}      nan
# 111     -50        False  calcdir  {'removesave': True}      nan
# 109     -50        False  calcdir  {'removesave': True}      nan
# 107     -50        False  calcdir  {'removesave': True}      nan
# 103     -50        False  calcdir  {'removesave': True}      nan
# 101     -50        False  calcdir  {'removesave': True}      nan
# 99      -50        False  calcdir  {'removesave': True}      nan
# 97      -50        False  calcdir  {'removesave': True}      nan
# 95      -50        False  calcdir  {'removesave': True}      nan
# 93      -50        False  calcdir  {'removesave': True}      nan
# 91      -50        False  calcdir  {'removesave': True}      nan
# 105     -50        False  calcdir  {'removesave': True}      nan
# 87      -50        False  calcdir  {'removesave': True}      nan
# 89      -50        False  calcdir  {'removesave': True}      nan
# 63      -50        False  calcdir  {'removesave': True}      nan
# 65      -50        False  calcdir  {'removesave': True}      nan
# 67      -50        False  calcdir  {'removesave': True}      nan
# 69      -50        False  calcdir  {'removesave': True}      nan
# 73      -50        False  calcdir  {'removesave': True}      nan
# 71      -50        False  calcdir  {'removesave': True}      nan
# 77      -50        False  calcdir  {'removesave': True}      nan
# 79      -50        False  calcdir  {'removesave': True}      nan
# 81      -50        False  calcdir  {'removesave': True}      nan
# 83      -50        False  calcdir  {'removesave': True}      nan
# 85      -50        False  calcdir  {'removesave': True}      nan
# 75      -50        False  calcdir  {'removesave': True}      nan
# ...     ...          ...      ...                   ...      ...
# 1837    -50        False  calcdir  {'removesave': True}      nan
# 1839    -50        False  calcdir  {'removesave': True}      nan
# 1841    -50        False  calcdir  {'removesave': True}      nan
# 1843    -50        False  calcdir  {'removesave': True}      nan
# 1845    -50        False  calcdir  {'removesave': True}      nan
# 1859    -50        False  calcdir  {'removesave': True}      nan
# 1849    -50        False  calcdir  {'removesave': True}      nan
# 1851    -50        False  calcdir  {'removesave': True}      nan
# 1853    -50        False  calcdir  {'removesave': True}      nan
# 1855    -50        False  calcdir  {'removesave': True}      nan
# 1857    -50        False  calcdir  {'removesave': True}      nan
# 1835    -50        False  calcdir  {'removesave': True}      nan
# 1847    -50        False  calcdir  {'removesave': True}      nan
# 1833    -50        False  calcdir  {'removesave': True}      nan
# 1819    -50        False  calcdir  {'removesave': True}      nan
# 1829    -50        False  calcdir  {'removesave': True}      nan
# 1827    -50        False  calcdir  {'removesave': True}      nan
# 1825    -50        False  calcdir  {'removesave': True}      nan
# 1823    -50        False  calcdir  {'removesave': True}      nan
# 1821    -50        False  calcdir  {'removesave': True}      nan
# 1817    -50        False  calcdir  {'removesave': True}      nan
# 1815    -50        False  calcdir  {'removesave': True}      nan
# 1813    -50        False  calcdir  {'removesave': True}      nan
# 1811    -50        False  calcdir  {'removesave': True}      nan
# 1809    -50        False  calcdir  {'removesave': True}      nan
# 1807    -50        False  calcdir  {'removesave': True}      nan
# 1801    -50        False  calcdir  {'removesave': True}      nan
# 1803    -50        False  calcdir  {'removesave': True}      nan
# 1831    -50        False  calcdir  {'removesave': True}      nan
# 1805    -50        False  calcdir  {'removesave': True}      nan
#
#      printensemble   pw  sigma        xc elec_energy_norm
# 61            True  600  0.005  BEEF-vdW         0.164829
# 119           True  600  0.005  BEEF-vdW         0.174838
# 117           True  600  0.005  BEEF-vdW         0.166314
# 115           True  600  0.005  BEEF-vdW         0.158191
# 113           True  600  0.005  BEEF-vdW         0.150409
# 111           True  600  0.005  BEEF-vdW         0.143146
# 109           True  600  0.005  BEEF-vdW         0.136349
# 107           True  600  0.005  BEEF-vdW         0.130025
# 103           True  600  0.005  BEEF-vdW         0.119313
# 101           True  600  0.005  BEEF-vdW         0.115016
# 99            True  600  0.005  BEEF-vdW          0.11138
# 97            True  600  0.005  BEEF-vdW         0.108066
# 95            True  600  0.005  BEEF-vdW         0.105575
# 93            True  600  0.005  BEEF-vdW         0.103672
# 91            True  600  0.005  BEEF-vdW         0.102335
# 105           True  600  0.005  BEEF-vdW         0.124418
# 87            True  600  0.005  BEEF-vdW         0.101733
# 89            True  600  0.005  BEEF-vdW         0.101818
# 63            True  600  0.005  BEEF-vdW         0.155257
# 65            True  600  0.005  BEEF-vdW         0.146919
# 67            True  600  0.005  BEEF-vdW          0.13941
# 69            True  600  0.005  BEEF-vdW          0.13257
# 73            True  600  0.005  BEEF-vdW         0.121262
# 71            True  600  0.005  BEEF-vdW         0.126484
# 77            True  600  0.005  BEEF-vdW         0.110538
# 79            True  600  0.005  BEEF-vdW          0.10753
# 81            True  600  0.005  BEEF-vdW         0.105152
# 83            True  600  0.005  BEEF-vdW         0.103355
# 85            True  600  0.005  BEEF-vdW         0.102231
# 75            True  600  0.005  BEEF-vdW         0.114045
# ...            ...  ...    ...       ...              ...
# 1837          True  600  0.005  BEEF-vdW         0.407423
# 1839          True  600  0.005  BEEF-vdW         0.421342
# 1841          True  600  0.005  BEEF-vdW         0.435721
# 1843          True  600  0.005  BEEF-vdW         0.450552
# 1845          True  600  0.005  BEEF-vdW         0.465678
# 1859          True  600  0.005  BEEF-vdW         0.582434
# 1849          True  600  0.005  BEEF-vdW         0.497199
# 1851          True  600  0.005  BEEF-vdW         0.513532
# 1853          True  600  0.005  BEEF-vdW         0.530259
# 1855          True  600  0.005  BEEF-vdW         0.547314
# 1857          True  600  0.005  BEEF-vdW         0.564728
# 1835          True  600  0.005  BEEF-vdW         0.393908
# 1847          True  600  0.005  BEEF-vdW         0.481274
# 1833          True  600  0.005  BEEF-vdW         0.380944
# 1819          True  600  0.005  BEEF-vdW         0.302629
# 1829          True  600  0.005  BEEF-vdW         0.356314
# 1827          True  600  0.005  BEEF-vdW         0.344632
# 1825          True  600  0.005  BEEF-vdW         0.333375
# 1823          True  600  0.005  BEEF-vdW          0.32259
# 1821          True  600  0.005  BEEF-vdW         0.312292
# 1817          True  600  0.005  BEEF-vdW         0.293577
# 1815          True  600  0.005  BEEF-vdW         0.285094
# 1813          True  600  0.005  BEEF-vdW         0.282724
# 1811          True  600  0.005  BEEF-vdW         0.275428
# 1809          True  600  0.005  BEEF-vdW         0.268674
# 1807          True  600  0.005  BEEF-vdW         0.262306
# 1801          True  600  0.005  BEEF-vdW         0.244886
# 1803          True  600  0.005  BEEF-vdW         0.250143
# 1831          True  600  0.005  BEEF-vdW         0.368402
# 1805          True  600  0.005  BEEF-vdW         0.255945
#
# [2500 rows x 28 columns]

# %% [markdown]
# # Plotting

# %%
axes_lab_size = 12 * (4./3.)
tick_lab_size = 9 * (4./3.)

common_axis_dict = {

    # "range": y_axis_range,
    "zeroline": False,
    "showline": True,
    "mirror": 'ticks',
    "linecolor": 'black',
    "showgrid": False,

    "titlefont": dict(size=axes_lab_size),
    "tickfont": dict(
        size=tick_lab_size,
        ),
    "ticks": 'inside',
    "tick0": 0,
    "tickcolor": 'black',
    # "dtick": 0.25,
    "ticklen": 2,
    "tickwidth": 1,
    }

layout = {
    "title": "Lattice constant bulk optmization (Ni, Co, Mo)",
    "titlefont": go.layout.Titlefont(size=24),

    "xaxis": dict(
        common_axis_dict,
        **{
            "title": "a",
#             "range": x_range,
            },
        ),

    "yaxis": dict(
        common_axis_dict,
        **{
            "title": "Electronic Energy (eV)",
#             "range": y_range,
            },
        ),

    "font": dict(
        family='Arial',
        # size=18,
        color='black',
        ),

#     "width": 1.5 * 18.7 * 37.795275591,
#     "height": 18.7 * 37.795275591,

    "showlegend": True,

    "legend": dict(
        # x=0.,
        # y=1.8,
        font=dict(
            size=10,
            ),
        ),
    }

# %%
fig = dict(data=data, layout=layout)

py.iplot(fig, filename='__temp__/basic-scatter')

# %%
# x_axis_interp
# interp_out = interp1d(
#     a_list,
#     energy_list,
#     kind="cubic",
#     )(x_axis_interp)

# %%
# min_ind = np.argmin(interp_out)
# interp_out[min_ind]
# x_axis_interp[min_ind]

# %%
# group_i["elec_energy_norm"].min()

# row_min = group_i[group_i['elec_energy_norm'] == group_i['elec_energy_norm'].min()]

# row_min["elec_energy_norm"].iloc[0]
# row_min["a"].iloc[0]


# min_i = go.Scatter(
#     x=[row_min["a"].iloc[0]],
#     y=[row_min["elec_energy_norm"].iloc[0]],
# #     interp1d(
# #         a_list,
# #         energy_list,
# #         kind="cubic",
# #         )(x_axis_interp),

#     mode='markers',
#     )

# data.append(min_i)

# %%
# from scipy.interpolate import interp1d

# x = np.linspace(0, 10, num=11, endpoint=True)
# y = np.cos(-x**2/9.0)
# # f = interp1d(x, y)
# f2 = interp1d(x, y, kind='cubic')

# f2()

# y=np.interp(
#     x_axis_interp,
#     a_list,
#     energy_list,
#     )

# interp1d(a_list, energy_list, kind='cubic')(x_axis_interp)

# %%
#     if no_c_latt_const is False:
#         print("sKLfjaskfsdj")
#         groupby = group_i.groupby(["c"])
#         for name_j, group_j in groupby:            
#             a_list = group_j["a"].tolist()
#             energy_list = group_j["elec_energy_norm"].tolist()

#             name_i = ""
#             for prop_i in prop_name_list:   
#                 name_i += str(group_j[prop_i].tolist()[0]) + "_"

#             name_i = name_i[0:-1]
            
#             data.append(go.Scatter(
#                 x=a_list,
#                 y=energy_list,
#                 mode='markers',
#                 name=name_i,
#                 marker = dict(
#                     size = 8,
#                     color = color_i,
# #                     line = dict(
# #                         width = 2,
# #                         color = 'rgb(0, 0, 0)'
# #                         )
#                     )
#                 ))

# %%
# if len(list(set(group_i["spinpol"].tolist()))) == 1:
#     spinpol = list(set(group_i["spinpol"].tolist()))[0]

# %%
# no_c_latt_const = all(np.isnan(group_i["c"].tolist()))
# all(
# np.isnan(group_i["c"].tolist())
# )

# %%
# x_axis_interp = np.linspace(
#     np.array(a_list).min(),
#     np.array(a_list).max(),
#     300,
#     )

# np.interp(
#     x_axis_interp,
#     a_list,
#     energy_list,
#     )

# interp_i = go.Scatter(
#     x=x_axis_interp,
#     y=np.interp(
#         x_axis_interp,
#         a_list,
#         energy_list,
#         ),

#     mode='lines',

# #     name=name_i,
# #     marker = dict(
# #         size = 8,
# #         color = color_i,
# # #                     line = dict(
# # #                         width = 2,
# # #                         color = 'rgb(0, 0, 0)'
# # #                         )
# #         )

#     )

# # data.append(interp_i)

# %%
# c_col = list(set(group_i["c"].tolist()))
# if len(c_col) == 1 and "nan" in c_col:
#     tmp = 42

# %%
# df_m

# df_m = df_m.replace(np.nan, 'nan', regex=True)

# %%
# a_list = group_i["a"].tolist()

# # if "c" in list()
# # c_list = group_i["c"].tolist()

# energy_list = group_i["elec_energy"].tolist()

# no_c_latt_const = all(np.isnan(group_i["c"].tolist()))

# if no_c_latt_const is False:
#     groupby = df_m.groupby(["c"])
#     for name_j, group_j in groupby:
#         tmp = 42

# name_i = ""
# for prop_i in prop_name_list:   
#     name_i += str(group_i[prop_i].tolist()[0]) + "_"

# name_i = name_i[0:-1]

# %%
# if len(list(set(group_i["support_metal"].tolist()))) == 1:
#     support_metal = list(set(group_i["support_metal"].tolist()))[0]

# %%
# data_points = go.Scatter3d(
#     x=a_lst,
#     y=b_a_lst,
#     z=elec_energy_lst,
#     mode='markers',
  
#     marker=dict(
#         size=6,
# #         color=elec_energy_lst,                # set color to an array/list of desired values
#         color="grey",                # set color to an array/list of desired values
# #         colorscale='magma',   # choose a colorscale
#         colorscale='Blackbody',   # choose a colorscale
#         opacity=1.
#         )    
#     )

# fig = go.Figure(data=[data_points], layout=layout2)
# py.iplot(fig, filename=pl_dir + '/pl_latt_opt_data_points')
