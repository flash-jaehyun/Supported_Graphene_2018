# %% [markdown]
# # FCC Iron 111 ORR <a name="head"></a>
# ***

# %% [markdown]
# #### Table of Contents
#
# -   [Import Python Modules](#import-modules)
# -   [Reference Energies & Misc Parameters](#ref_e_&_params)
# -   [Initialize Instances](#init_instances)
# -   [Lowest Energy Pathway](#lowest_e_pathway)
# -   [All Binding Site States](#all_states)

# %% [markdown]
# ## Import Modules <a name="import-modules"></a>

# %%
import sys
import copy

import numpy as np
import pandas as pd

import plotly
from plotly.graph_objs import Figure
import plotly.plotly as py

# My Modules ******************************************************************
from dft_job_automat.job_analysis import DFT_Jobs_Analysis
from dft_job_automat.job_types_classes.dft_methods import DFT_Methods
from orr_reaction.orr_methods import ORR_Free_E_Plot, calc_ads_e

from orr_reaction.orr_methods import lowest_e_path, df_calc_adsorption_e, plot_all_states

pd.options.mode.chained_assignment = None

# iPython Settings
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Reference Energies & Misc Parameters <a name="ref_e_&_params"></a>

# %%
# bare_slab = -31722.43520417364

bare_slab_False = -30772.862053560006
bare_slab_True = -30774.394355700322

bare_slab_dict = {True: bare_slab_True, False: bare_slab_False}

# R21 From Pourbaix Papers
dG_rxn_h2o = -2.4583

# /scratch/users/flores12/gas_phase_molec/BEEF-vdW
H2_dft = -32.9563981542851
O2_dft = -883.190570481887
H2O_dft = -476.544109028354

hyd_ref = H2_dft / 2.

ref_scheme = "h2o"
if ref_scheme == "h2o":
    oxy_ref = H2O_dft - H2_dft
elif ref_scheme == "o2":
    oxy_ref = dG_rxn_h2o + O2_dft / 2.
    
color_list = [
    "rgb(113,166,190)",
    "rgb(145,209,79)",
    "rgb(124,78,196)",
    "rgb(203,169,87)",
    "rgb(200,72,150)",
    "rgb(130,204,159)",
    "rgb(190,82,63)",
    "rgb(80,51,82)",
    "rgb(81,92,54)",
    "rgb(192,151,188)",
    ]

# %% [markdown]
# ## Initialize Instances <a name="init_instances"></a>

# %%
dft_inst = DFT_Methods(
    methods_to_run=[
        "elec_energy",
        "gibbs_correction",
        "atom_type_num_dict",
        "init_atoms",
        "atoms_object",
        # "magmom_charge_history",
        ],
    )

Jobs = DFT_Jobs_Analysis(
    update_job_state=False,
    job_type_class=dft_inst,
    load_dataframe=True,
    # load_dataframe=False,
    working_dir="1STEP",
    )

df = Jobs.filter_early_revisions(Jobs.data_frame)
df_calc_adsorption_e(df, oxy_ref, hyd_ref, bare_slab_dict, bare_slab_var="spinpol", )
df_master = df.copy()

# %% [markdown]
# ## All Binding Site States <a name="all_states"></a>

# %%
dat_lst1, layout1 = plot_all_states(
    df_master,
    Jobs.tree_level_labels,
    color_list,
    bias=0.,
    plot_title="FED For ORR on FCC Fe(111)"
    )

py.iplot(
    {
        "data": dat_lst1,
        "layout": layout1,
        },
    filename="pl_fed_supp_graph_01.html"
    )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~flores12/144.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Lowest Energy Pathway <a name="lowest_e_pathway"></a>

# %%
dat_lst, layout = lowest_e_path(
    df,
    Jobs.tree_level_labels,
    color_list,
    bias=0.,
    plot_title="FED For ORR on FCC Fe(111)",
    )

py.iplot(
    {
        "data": dat_lst,
        "layout": layout,
        },
    filename="pl_fed_supp_graph_02.html"
    )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~flores12/142.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# [(Back to top)](#head)

# %%
# from dft_job_automat.job_types_classes.data_frame_methods import DataFrame_Methods
# DF = DataFrame_Methods(df_master)

# DF.create_atoms_objects()

# for index, row in df_master.iterrows():
#     print(row["full_path"])


df_master
# Out:
#    adsorbate  max_revision                              path  revision_number  \
# 0        ooh             1     data/01-ooh/01-ontop/01-True/                1
# 1        ooh             1    data/01-ooh/01-ontop/02-False/                1
# 2        ooh             1    data/01-ooh/02-bridge/01-True/                1
# 3        ooh             1   data/01-ooh/02-bridge/02-False/                1
# 4        ooh             1   data/01-ooh/03-trifold/01-True/                1
# 5        ooh             1  data/01-ooh/03-trifold/02-False/                1
# 6          o             1       data/02-o/01-ontop/01-True/                1
# 7          o             1      data/02-o/01-ontop/02-False/                1
# 8          o             1      data/02-o/02-bridge/01-True/                1
# 9          o             1     data/02-o/02-bridge/02-False/                1
# 10         o             1     data/02-o/03-trifold/01-True/                1
# 11         o             1    data/02-o/03-trifold/02-False/                1
# 12        oh             1      data/03-oh/01-ontop/01-True/                1
# 13        oh             1     data/03-oh/01-ontop/02-False/                1
# 14        oh             1     data/03-oh/02-bridge/01-True/                1
# 15        oh             1    data/03-oh/02-bridge/02-False/                1
# 16        oh             1    data/03-oh/03-trifold/01-True/                1
# 17        oh             1   data/03-oh/03-trifold/02-False/                1
# 18       h2o             1     data/04-h2o/01-ontop/01-True/                1
# 19       h2o             1    data/04-h2o/01-ontop/02-False/                1
# 20       h2o             1    data/04-h2o/02-bridge/01-True/                1
# 21       h2o             1   data/04-h2o/02-bridge/02-False/                1
# 22       h2o             1   data/04-h2o/03-trifold/01-True/                1
# 23       h2o             1  data/04-h2o/03-trifold/02-False/                1
#
#        site  spinpol                                      variable_list  \
# 0     ontop     True  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 1     ontop    False  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 2    bridge     True  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 3    bridge    False  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 4   trifold     True  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 5   trifold    False  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 6     ontop     True  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 7     ontop    False  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 8    bridge     True  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 9    bridge    False  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 10  trifold     True  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 11  trifold    False  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 12    ontop     True  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 13    ontop    False  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 14   bridge     True  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 15   bridge    False  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 16  trifold     True  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 17  trifold    False  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 18    ontop     True  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
# 19    ontop    False  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
# 20   bridge     True  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
# 21   bridge    False  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
# 22  trifold     True  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
# 23  trifold    False  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
#
#      elec_energy  gibbs_correction           atom_type_num_dict  \
# 0  -31675.152564          0.266442  [{'H': 1, 'Fe': 9, 'O': 2}]
# 1  -31676.119572          0.444851  [{'H': 1, 'Fe': 9, 'O': 2}]
# 2  -31678.485264          0.349077  [{'H': 1, 'Fe': 9, 'O': 2}]
# 3  -31676.746138          0.433805  [{'H': 1, 'Fe': 9, 'O': 2}]
# 4            NaN          0.000000                          NaN
# 5  -31676.119317          0.448172  [{'H': 1, 'Fe': 9, 'O': 2}]
# 6  -31217.452721          0.047717          [{'Fe': 9, 'O': 1}]
# 7  -31215.523681          0.053283          [{'Fe': 9, 'O': 1}]
# 8  -31218.636224          0.049566          [{'Fe': 9, 'O': 1}]
# 9  -31217.066226          0.071609          [{'Fe': 9, 'O': 1}]
# 10 -31218.068223          0.061294          [{'Fe': 9, 'O': 1}]
# 11 -31217.066200          0.071770          [{'Fe': 9, 'O': 1}]
# 12 -31234.596265          0.231066  [{'H': 1, 'Fe': 9, 'O': 1}]
# 13 -31233.140183          0.294713  [{'H': 1, 'Fe': 9, 'O': 1}]
# 14 -31235.027482          0.269872  [{'H': 1, 'Fe': 9, 'O': 1}]
# 15 -31233.140062          0.299891  [{'H': 1, 'Fe': 9, 'O': 1}]
# 16 -31235.024034          0.257610  [{'H': 1, 'Fe': 9, 'O': 1}]
# 17 -31233.140158          0.293324  [{'H': 1, 'Fe': 9, 'O': 1}]
# 18 -31250.988767          0.497784  [{'H': 2, 'Fe': 9, 'O': 1}]
# 19 -31249.436317          0.551685  [{'H': 2, 'Fe': 9, 'O': 1}]
# 20 -31251.355545          0.578383  [{'H': 2, 'Fe': 9, 'O': 1}]
# 21 -31249.437806          0.564042  [{'H': 2, 'Fe': 9, 'O': 1}]
# 22           NaN          0.000000                          NaN
# 23 -31249.437448          0.466046  [{'H': 2, 'Fe': 9, 'O': 1}]
#
#                                            init_atoms  \
# 0   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 1   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 2   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 3   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 4   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 5   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 6   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 7   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 8   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 9   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 10  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 11  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 12  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 13  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 14  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 15  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 16  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 17  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 18  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 19  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 20  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 21  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 22  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 23  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
#
#                                          atoms_object  NA  \
# 0   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 1   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 2   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 3   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 4                                                None NaN
# 5   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 6   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 7   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 8   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 9   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 10  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 11  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 12  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 13  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 14  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 15  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 16  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 17  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 18  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 19  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 20  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 21  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
# 22                                               None NaN
# 23  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t... NaN
#
#                                        charge_history  \
# 0       atom_num  iteration element  charge
# 0     ...
# 1                                                 NaN
# 2       atom_num  iteration element  charge
# 0     ...
# 3                                                 NaN
# 4       atom_num  iteration element  charge
# 0     ...
# 5                                                 NaN
# 6       atom_num  iteration element  charge
# 0     ...
# 7                                                 NaN
# 8       atom_num  iteration element  charge
# 0     ...
# 9                                                 NaN
# 10      atom_num  iteration element  charge
# 0     ...
# 11                                                NaN
# 12      atom_num  iteration element  charge
# 0     ...
# 13                                                NaN
# 14      atom_num  iteration element  charge
# 0     ...
# 15                                                NaN
# 16      atom_num  iteration element  charge
# 0     ...
# 17                                                NaN
# 18      atom_num  iteration element  charge
# 0     ...
# 19                                                NaN
# 20      atom_num  iteration element  charge
# 0     ...
# 21                                                NaN
# 22      atom_num  iteration element  charge
# 0     ...
# 23                                                NaN
#
#                                        magmom_history  \
# 0       atom_num  iteration element  magmom
# 0     ...
# 1                                                 NaN
# 2       atom_num  iteration element  magmom
# 0     ...
# 3                                                 NaN
# 4       atom_num  iteration element  magmom
# 0     ...
# 5                                                 NaN
# 6       atom_num  iteration element  magmom
# 0     ...
# 7                                                 NaN
# 8       atom_num  iteration element  magmom
# 0     ...
# 9                                                 NaN
# 10      atom_num  iteration element  magmom
# 0     ...
# 11                                                NaN
# 12      atom_num  iteration element  magmom
# 0     ...
# 13                                                NaN
# 14      atom_num  iteration element  magmom
# 0     ...
# 15                                                NaN
# 16      atom_num  iteration element  magmom
# 0     ...
# 17                                                NaN
# 18      atom_num  iteration element  magmom
# 0     ...
# 19                                                NaN
# 20      atom_num  iteration element  magmom
# 0     ...
# 21                                                NaN
# 22      atom_num  iteration element  magmom
# 0     ...
# 23                                                NaN
#
#                              full_path  notes     ads_e
# 0      data/01-ooh/01-ontop/01-True/_1    NaN  3.161855
# 1     data/01-ooh/01-ontop/02-False/_1    NaN  0.840953
# 2     data/01-ooh/02-bridge/01-True/_1    NaN -0.088211
# 3    data/01-ooh/02-bridge/02-False/_1    NaN  0.203341
# 4    data/01-ooh/03-trifold/01-True/_1    NaN       NaN
# 5   data/01-ooh/03-trifold/02-False/_1    NaN  0.844529
# 6        data/02-o/01-ontop/01-True/_1    NaN  0.577063
# 7       data/02-o/01-ontop/02-False/_1    NaN  0.979366
# 8       data/02-o/02-bridge/01-True/_1    NaN -0.604592
# 9      data/02-o/02-bridge/02-False/_1    NaN -0.544853
# 10     data/02-o/03-trifold/01-True/_1    NaN -0.024863
# 11    data/02-o/03-trifold/02-False/_1    NaN -0.544666
# 12      data/03-oh/01-ontop/01-True/_1    NaN  0.095067
# 13     data/03-oh/01-ontop/02-False/_1    NaN  0.082494
# 14     data/03-oh/02-bridge/01-True/_1    NaN -0.297344
# 15    data/03-oh/02-bridge/02-False/_1    NaN  0.087793
# 16    data/03-oh/03-trifold/01-True/_1    NaN -0.306159
# 17   data/03-oh/03-trifold/02-False/_1    NaN  0.081129
# 18     data/04-h2o/01-ontop/01-True/_1    NaN  0.447481
# 19    data/04-h2o/01-ontop/02-False/_1    NaN  0.521530
# 20    data/04-h2o/02-bridge/01-True/_1    NaN  0.161302
# 21   data/04-h2o/02-bridge/02-False/_1    NaN  0.532399
# 22   data/04-h2o/03-trifold/01-True/_1    NaN       NaN
# 23  data/04-h2o/03-trifold/02-False/_1    NaN  0.434760
