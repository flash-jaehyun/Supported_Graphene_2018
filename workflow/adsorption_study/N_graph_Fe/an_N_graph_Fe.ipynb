# %% [markdown]
# # Nitrogen-doped Graphene Supported on FCC Iron 111 Surface <a name="head"></a>
# ***

# %% [markdown]
# #### Table of Contents
#
# -   [Import Python Modules](#import-modules)
# -   [Reference Energies & Misc Parameters](#ref_e_&_params)
# -   [Initialize Instances](#init_instances)
# -   [Lowest Energy Pathway](#lowest_e_pathway)
# -   [All Binding Site States](#all_states)

# %% [markdown]
# ## Import Modules <a name="import-modules"></a>

# %%
import sys
import copy

import numpy as np
import pandas as pd

import plotly
from plotly.graph_objs import Figure
import plotly.plotly as py

# My Modules ******************************************************************
from dft_job_automat.job_analysis import DFT_Jobs_Analysis
from dft_job_automat.job_types_classes.dft_methods import DFT_Methods
from orr_reaction.orr_methods import ORR_Free_E_Plot, calc_ads_e

from orr_reaction.orr_methods import lowest_e_path, df_calc_adsorption_e, plot_all_states
from energetics.dft_energy import Element_Refs

pd.options.mode.chained_assignment = None

# iPython Settings
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Reference Energies & Misc Parameters <a name="ref_e_&_params"></a>

# %%
bare_slab = -31839.06523325643

# bare_slab_NGraph_Fe = -31839.06523325643

# /scratch/users/flores12/03_graph_N_Fe/01_opt_struct/N_doped_graph_Fe/no_spin/01_N_trifold/_4
bare_slab_NGraph_Fe_Ctrifold = -31838.6148526
bare_slab_NGraph_Fe_Ntrifold = -31839.06523325643

bare_slab_dict = {
    "C-trifold": bare_slab_NGraph_Fe_Ctrifold,
    "N-trifold": bare_slab_NGraph_Fe_Ntrifold,
    }

fe_corr_dict = {
    "h2o": 0.5290403581846084,
    "o": 0.0777295188024034,
    "oh": 0.3278711654655712,
    "ooh": 0.35756420469723127,
    }

Refs = Element_Refs()
oxy_ref = Refs.E_O_ref.gibbs_e
hyd_ref = Refs.E_H_ref.gibbs_e

# R21 From Pourbaix Papers
dG_rxn_h2o = -2.4583

color_list = [
    "rgb(113,166,190)",
    "rgb(145,209,79)",
    "rgb(124,78,196)",
    "rgb(203,169,87)",
    "rgb(200,72,150)",
    "rgb(130,204,159)",
    "rgb(190,82,63)",
    "rgb(80,51,82)",
    "rgb(81,92,54)",
    "rgb(192,151,188)",
    ]
# Out:
# __truediv__
# Divisor is integer or float
# <class 'float'>
# KJFKDSJKFJDSLJFLISDJFIJSDKFJKDS -------------------------
# Divisor is Energy class instance!!!
# KJFKDSJKFJDSLJFLISDJFIJSDKFJKDS -------------------------

# %% [markdown]
# ## Initialize Instances <a name="init_instances"></a>

# %%
dft_inst = DFT_Methods(
    methods_to_run=[
        "elec_energy",
        "gibbs_correction",
        "atom_type_num_dict",
        "init_atoms",
        "atoms_object",
        # "magmom_charge_history",
        ],
    )

Jobs = DFT_Jobs_Analysis(
    update_job_state=False,
    job_type_class=dft_inst,
    load_dataframe=True,
    # load_dataframe=False,
    working_dir="1STEP",
    )


df = Jobs.filter_early_revisions(Jobs.data_frame)


# if folder_name == "N_graph_Fe":
#     df_calc_adsorption_e(df, oxy_ref, hyd_ref, row["bare_ref"], bare_slab_var="spinpol")
# else:
#     df_calc_adsorption_e(df, oxy_ref, hyd_ref, row["bare_ref"], bare_slab_var="spinpol", corrections_mode="corr_dict", corrections_dict=fe_corr_dict)

    
df_calc_adsorption_e(
    df,
    oxy_ref,
    hyd_ref,
    bare_slab_dict,
    bare_slab_var="graph_site",
    corrections_mode="df_column",
    corrections_dict=fe_corr_dict,
    )


df_master = df.copy()
# Out:
# Using correction dict
# Using correction dict
# Using correction dict

# %% [markdown]
# ## All Binding Site States <a name="all_states"></a>

# %%
# for index, row in df.iterrows():
#     if row["final_site"] == "":
#         df.at[index, "final_site"] = df.at[index, "site"]

# %%
#df[(df["final_site"] == "C-ontop-trifold") & (df["adsorbate"] == "ooh")]

df
# Out:
#    adsorbate  max_revision                             path  revision_number  \
# 1        ooh             2      data/01-ooh/01-ring-center/                2
# 3        ooh             2          data/01-ooh/02-N-ontop/                2
# 5        ooh             2    data/01-ooh/03-C-ontop-ontop/                2
# 7        ooh             2  data/01-ooh/04-C-ontop-trifold/                2
# 9        ooh             2      data/01-ooh/05-C-C-bridged/                2
# 11       ooh             2      data/01-ooh/06-C-N-bridged/                2
# 12         o             1        data/02-o/01-ring-center/                1
# 13         o             1            data/02-o/02-N-ontop/                1
# 14         o             1      data/02-o/03-C-ontop-ontop/                1
# 15         o             1    data/02-o/04-C-ontop-trifold/                1
# 16         o             1        data/02-o/05-C-C-bridged/                1
# 17         o             1        data/02-o/06-C-N-bridged/                1
# 19        oh             2       data/03-oh/01-ring-center/                2
# 21        oh             2           data/03-oh/02-N-ontop/                2
# 23        oh             2     data/03-oh/03-C-ontop-ontop/                2
# 24        oh             1   data/03-oh/04-C-ontop-trifold/                1
# 26        oh             2       data/03-oh/05-C-C-bridged/                2
# 27        oh             1       data/03-oh/06-C-N-bridged/                1
# 29       h2o             2      data/04-h2o/01-ring-center/                2
# 31       h2o             2          data/04-h2o/02-N-ontop/                2
# 33       h2o             2    data/04-h2o/03-C-ontop-ontop/                2
# 35       h2o             2  data/04-h2o/04-C-ontop-trifold/                2
# 37       h2o             2      data/04-h2o/05-C-C-bridged/                2
# 39       h2o             2      data/04-h2o/06-C-N-bridged/                2
#
#                site                                      variable_list  \
# 1       ring-center  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 3           N-ontop  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 5     C-ontop-ontop  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 7   C-ontop-trifold  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 9       C-C-bridged  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 11      C-N-bridged  [{'property': 'adsorbate', 'value': 'ooh'}, {'...
# 12      ring-center  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 13          N-ontop  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 14    C-ontop-ontop  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 15  C-ontop-trifold  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 16      C-C-bridged  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 17      C-N-bridged  [{'property': 'adsorbate', 'value': 'o'}, {'pr...
# 19      ring-center  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 21          N-ontop  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 23    C-ontop-ontop  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 24  C-ontop-trifold  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 26      C-C-bridged  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 27      C-N-bridged  [{'property': 'adsorbate', 'value': 'oh'}, {'p...
# 29      ring-center  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
# 31          N-ontop  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
# 33    C-ontop-ontop  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
# 35  C-ontop-trifold  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
# 37      C-C-bridged  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
# 39      C-N-bridged  [{'property': 'adsorbate', 'value': 'h2o'}, {'...
#
#      elec_energy  gibbs_correction  \
# 1  -32739.128128          0.411233
# 3  -32738.439102          0.283858
# 5  -32739.468382          0.000000
# 7  -32739.128166          0.414147
# 9  -32738.396377          0.321019
# 11 -32739.131472          0.000000
# 12 -32281.422248          0.087233
# 13 -32279.649902          0.070073
# 14 -32281.422275          0.087479
# 15 -32280.403668          0.068635
# 16 -32280.176610          0.082960
# 17 -32279.649903          0.069997
# 19 -32298.886149          0.362246
# 21 -32297.054482          0.248155
# 23 -32298.909220          0.376159
# 24 -32298.574166          0.367089
# 26 -32298.574178          0.369657
# 27 -32297.054515          0.243921
# 29 -32316.055270          0.518781
# 31 -32316.054145          0.506897
# 33 -32316.050726          0.000000
# 35 -32316.054934          0.540669
# 37 -32316.055472          0.534086
# 39 -32316.050556          0.544770
#
#                              atom_type_num_dict  \
# 1   [{'H': 1, 'C': 5, 'Fe': 9, 'O': 2, 'N': 1}]
# 3   [{'H': 1, 'C': 5, 'Fe': 9, 'O': 2, 'N': 1}]
# 5   [{'H': 1, 'C': 5, 'Fe': 9, 'O': 2, 'N': 1}]
# 7   [{'H': 1, 'C': 5, 'Fe': 9, 'O': 2, 'N': 1}]
# 9   [{'H': 1, 'C': 5, 'Fe': 9, 'O': 2, 'N': 1}]
# 11  [{'H': 1, 'C': 5, 'Fe': 9, 'O': 2, 'N': 1}]
# 12          [{'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 13          [{'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 14          [{'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 15          [{'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 16          [{'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 17          [{'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 19  [{'H': 1, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 21  [{'H': 1, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 23  [{'H': 1, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 24  [{'H': 1, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 26  [{'H': 1, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 27  [{'H': 1, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 29  [{'H': 2, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 31  [{'H': 2, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 33  [{'H': 2, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 35  [{'H': 2, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 37  [{'H': 2, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
# 39  [{'H': 2, 'C': 5, 'Fe': 9, 'O': 1, 'N': 1}]
#
#                                            init_atoms  \
# 1   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 3   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 5   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 7   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 9   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 11  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 12  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 13  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 14  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 15  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 16  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 17  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 19  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 21  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 23  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 24  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 26  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 27  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 29  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 31  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 33  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 35  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 37  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 39  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
#
#                                          atoms_object  \
# 1   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 3   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 5   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 7   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 9   [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 11  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 12  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 13  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 14  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 15  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 16  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 17  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 19  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 21  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 23  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 24  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 26  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 27  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 29  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 31  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 33  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 35  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 37  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
# 39  [(Atom('Fe', [3.90031231, 0.61413992, 12.0], t...
#
#                             full_path       final_site graph_site     notes  \
# 1       data/01-ooh/01-ring-center/_2  C-ontop-trifold  N-trifold
# 3           data/01-ooh/02-N-ontop/_2                   N-trifold  Desorbed
# 5     data/01-ooh/03-C-ontop-ontop/_2  C-ontop-trifold  C-trifold
# 7   data/01-ooh/04-C-ontop-trifold/_2                   N-trifold
# 9       data/01-ooh/05-C-C-bridged/_2                   N-trifold  Desorbed
# 11      data/01-ooh/06-C-N-bridged/_2  C-ontop-trifold  N-trifold
# 12        data/02-o/01-ring-center/_1  C-ontop-trifold  C-trifold
# 13            data/02-o/02-N-ontop/_1                   N-trifold
# 14      data/02-o/03-C-ontop-ontop/_1  C-ontop-trifold  C-trifold
# 15    data/02-o/04-C-ontop-trifold/_1                   N-trifold
# 16        data/02-o/05-C-C-bridged/_1                   N-trifold
# 17        data/02-o/06-C-N-bridged/_1  N-ontop-trifold  N-trifold
# 19       data/03-oh/01-ring-center/_2  C-ontop-trifold  C-trifold
# 21           data/03-oh/02-N-ontop/_2  N-ontop-trifold  N-trifold  Desorbed
# 23     data/03-oh/03-C-ontop-ontop/_2  C-ontop-trifold  C-trifold
# 24   data/03-oh/04-C-ontop-trifold/_1                   N-trifold
# 26       data/03-oh/05-C-C-bridged/_2  C-ontop-trifold  N-trifold
# 27       data/03-oh/06-C-N-bridged/_1  N-ontop-trifold  N-trifold  Desorbed
# 29      data/04-h2o/01-ring-center/_2                   N-trifold  Desorbed
# 31          data/04-h2o/02-N-ontop/_2                   N-trifold  Desorbed
# 33    data/04-h2o/03-C-ontop-ontop/_2                   N-trifold  Desorbed
# 35  data/04-h2o/04-C-ontop-trifold/_2                   N-trifold  Desorbed
# 37      data/04-h2o/05-C-C-bridged/_2                   N-trifold  Desorbed
# 39      data/04-h2o/06-C-N-bridged/_2                   N-trifold  Desorbed
#
#        ads_e
# 1   4.002371
# 3   4.564022
# 5   3.158067
# 7   4.005248
# 9   4.643908
# 11  3.945358
# 12  0.867824
# 13  3.073390
# 14  0.868042
# 15  2.318185
# 16  2.559569
# 17  3.073313
# 19  0.156997
# 21  2.324954
# 23  0.147839
# 24  0.924204
# 26  0.926760
# 27  2.320686
# 29  0.072852
# 31  0.062094
# 33  0.087657
# 35  0.095077
# 37  0.087956
# 39  0.103556

# %%
dat_lst1, layout1 = plot_all_states(
    df,
    Jobs.tree_level_labels,
    color_list,
    bias=0.,
    hover_text_col=["final_site", "graph_site", "notes"],
    #hover_text_col="final_site",
    plot_title="FED For N-Doped Graphene Supported on FCC Fe(111)",
    )

py.iplot(
    {
        "data": dat_lst1,
        "layout": layout1,
        },
    filename="pl_fed_supp_graph_01.html"
    )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~flores12/144.embed" height="600.0px" width="800.0px"></iframe>

# %% [markdown]
# ## Lowest Energy Pathway <a name="lowest_e_pathway"></a>

# %%
dat_lst, layout = lowest_e_path(
    df,
    Jobs.tree_level_labels,
    color_list,
    bias=0.,
    plot_title="FED For N-Doped Graphene Supported on FCC Fe(111)",
    )

py.iplot(
    {
        "data": dat_lst,
        "layout": layout,
        },
    filename="pl_fed_supp_graph_02.html"
    )
# Out:
# 180501 - kjkskfksdjfjwiaujfklasdnvfjsdkgjsakdlfdjuihg;jwkljfsd
# [nan, 'C-ontop-ontop', 'ring-center', 'C-ontop-ontop', nan]
# __
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~flores12/142.embed" height="600.0px" width="800.0px"></iframe>

# %% [markdown]
# [(Back to top)](#head)
