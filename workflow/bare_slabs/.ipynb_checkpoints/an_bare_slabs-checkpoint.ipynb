# %% [markdown]
# ### Import Modules <a name="import-modules"></a>

# %%
# iPython Settings
# %load_ext autoreload
# %autoreload 2

import plotly as py
import plotly.graph_objs as go
from plotly import tools

import pandas as pd
pd.options.mode.chained_assignment = None

from ase.visualize import view

# My Modules ******************************************************************
from dft_job_automat.job_analysis import DFT_Jobs_Analysis
from dft_job_automat.job_types_classes.dft_methods import DFT_Methods
from colors.colors import color_list

# from density_of_states.dos import plot_pdos_dos
from dft_post_analysis.bands import plot_bands
from dft_post_analysis.dos import plot_pdos_dos

from dft_post_analysis.dos_bands_combined import plot_pdos_bands
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Initiate Instance

# %%
Jobs = DFT_Jobs_Analysis(
    update_job_state=False,
    job_type_class=None,
    load_dataframe=True,
    dataframe_dir="jobs_bin",
    working_dir=".",
    )

df = Jobs.filter_early_revisions(Jobs.data_frame)

# Selecting Relevent Columns
df = df[
    [
        'job_type',

#         'max_revision',
#         'revision_number',

        'overlayer_pos',
        'path',
        'spinpol',
        'system',
        'elec_energy',
        'pdos_data',
        'bands_data',
        'init_atoms',
        
        ]
    ]

# df["path_short"] = df["path"][-4:]
df["path_short"] = df["path"].apply(lambda x: "/".join(x.split("/")[5:]))
# Out:
# Couldn't read /jobs_bin/dir_structure.json
# old - Reading dir_structure.json file                         from root_dir
# Couldn't read /dir_structure.json

# %% [markdown]
# ### Script Inputs

# %%
df
# Out:
#      job_type overlayer_pos  \
# 1   bare_slab           NaN
# 4   bare_slab           NaN
# 5   bare_slab           NaN
# 6   bare_slab           NaN
# 10        NaN           NaN
# 12  bare_slab           NaN
# 13  bare_slab     N_trifold
# 15        NaN           NaN
# 16  bare_slab           NaN
# 18  bare_slab           NaN
#
#                                                  path spinpol      system  \
# 1   /scratch/users/flores12/03_graph_N_Fe/01_opt_s...    True     Fe_slab
# 4   /scratch/users/flores12/03_graph_N_Fe/01_opt_s...   False     Fe_slab
# 5   /scratch/users/flores12/03_graph_N_Fe/01_opt_s...    True    graphene
# 6   /scratch/users/flores12/03_graph_N_Fe/01_opt_s...   False    graphene
# 10  /scratch/users/flores12/03_graph_N_Fe/01_opt_s...     NaN         NaN
# 12  /scratch/users/flores12/03_graph_N_Fe/01_opt_s...   False    graph_Fe
# 13  /scratch/users/flores12/03_graph_N_Fe/01_opt_s...   False  N_graph_Fe
# 15  /scratch/users/flores12/03_graph_N_Fe/01_opt_s...     NaN         NaN
# 16  /scratch/users/flores12/03_graph_N_Fe/01_opt_s...    True  N_graphene
# 18  /scratch/users/flores12/03_graph_N_Fe/01_opt_s...   False  N_graphene
#
#      elec_energy  pdos_data  bands_data  \
# 1  -30774.394360        NaN         NaN
# 4  -30772.862060        NaN         NaN
# 5    -947.901039        NaN         NaN
# 6    -947.901170        NaN         NaN
# 10           NaN        NaN         NaN
# 12 -31721.379279        NaN         NaN
# 13 -31839.086947        NaN         NaN
# 15 -31838.601462        NaN         NaN
# 16  -1065.408439        NaN         NaN
# 18  -1065.408418        NaN         NaN
#
#                                            init_atoms  \
# 1   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 4   (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 5   (Atom('C', [0.3550598067381865, -0.61474448424...
# 6   (Atom('C', [0.3550598067381865, -0.61474448424...
# 10  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 12  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 13  (Atom('Fe', [3.90031231, 0.61413992, 12.0], ta...
# 15                                               None
# 16  (Atom('C', [0.35491197408025293, -0.6149216084...
# 18  (Atom('C', [0.35491197408025293, -0.6149216084...
#
#                                            path_short
# 1   03_graph_N_Fe/01_opt_struct/Fe/slab/1-att/yes_...
# 4   03_graph_N_Fe/01_opt_struct/Fe/slab/1-att/no_s...
# 5   03_graph_N_Fe/01_opt_struct/graphene/spinpol_T...
# 6   03_graph_N_Fe/01_opt_struct/graphene/spinpol_F...
# 10  03_graph_N_Fe/01_opt_struct/combined-Fe-graph/...
# 12  03_graph_N_Fe/01_opt_struct/combined-Fe-graph/...
# 13  03_graph_N_Fe/01_opt_struct/N_doped_graph_Fe/n...
# 15  03_graph_N_Fe/01_opt_struct/N_doped_graph_Fe/n...
# 16  03_graph_N_Fe/01_opt_struct/N_graph/spinpol_Tr...
# 18  03_graph_N_Fe/01_opt_struct/N_graph/spinpol_Fa...

# %%
# tmp = df.iloc[0].path
# "/".join(tmp.split("/")[4:])

# %%
# df.loc[11].path
