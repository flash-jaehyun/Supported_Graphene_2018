# %%
# if save_plot:
#     save_dir = proj_dir_name
# else:
#     save_dir = "__temp__"

# layout = ORR_PLT.plotly_fed_layout(
#     plot_title="",
#     plot_width=1.5 * 680,
#     plot_height=1.5 * 510,
#     )

# py.plotly.iplot(
#     {
#         "data": ORR_PLT.plotly_data(),
#         "layout": layout,
#         },
#         filename=os.path.join(save_dir, "pl_fed_all_systems"),
#     )

# col_order_list = [
#     "system",
#     "adsorbate",
#     "site",
#     "final_site",
#     "spinpol",
#     "graph_site",

#     "ads_e",
#     "gibbs_correction",
#     "elec_energy",

#     "path",
#     "full_path",

#     "notes",
#     "variable_list",
#     "atom_type_num_dict",
#     "tree_level_labels",

#     "revision_number",
#     "max_revision",

#     "init_atoms",
#     "atoms_object",

#     "Job",
#     ]


# col_order_list.reverse()

# df_col_list = list(df_m)
# for col_i in col_order_list:  
#     df_col_list.remove(col_i)
    
#     df_col_list.insert(0, col_i)

# energy_dict = VP.create_volcano_lines(
#     gas_molec_dict=gas_molec_dict,
#     scaling_dict=scaling_dict,
#     )


# lst = [
#     energy_dict["o2_to_ooh"],
#     energy_dict["ooh_to_o"],
#     energy_dict["o_to_oh"],
#     energy_dict["oh_to_h2o"],
#     ]

# lst1 = [1,2,3]

# lst1.append(4)

# lst1

# def meth_1(lst1, lst2, lst3, lst4):
#     print("Hello")
    
#     print(len(lst1))
#     print(len(lst2))
#     print(len(lst3))
#     print(len(lst4))

# meth_1(*lst)

# all_columns = set(list(df_m))

# exclude_columns = set([
#     "pdos_data",
#     "charge_history",
#     ])

# columns_to_keep = list(all_columns - exclude_columns)

# df_m = df_m[columns_to_keep]



#     df_i = pd.DataFrame(df_list_i)
    
#     ORR_PLT.add_series(
#         df_i,
#         plot_mode="all",
#         opt_name="tmp2",
#         overpotential_type="ORR",
# #         system_properties=prop_list_i,
#         color="red",
#         )

# for key_j, value_j in row_i.iteritems():
    
#     if key_j == "dg_ads_o":
#         continue
#     elif key_j == "df_ads_oh":
#         continue
#     elif key_j == "d_ads_ooh":
#         continue

#     df_list_i[key_j] = value_j

# properties_string_name = ""
# for key_i, value_i in prop_list_i.items():
    
#     properties_string_name += str(key_i)
#     properties_string_name += "_"
#     properties_string_name += str(value_i)
    
#     properties_string_name += " | "

# properties_string_name = properties_string_name[0:-3]

#     prop_list_i = {}
#     for prop_i in prop_name_list:    
#         first_value = df_i[prop_i].tolist()[0]
#         all_same_value = all([True if i == first_value else False for i in df_i[prop_i].tolist()])

#         if all_same_value:
#             prop_list_i[prop_i] = str(first_value)
#         else:
#             prop_list_i[prop_i] = str(None)
#     name_i = "_".join(list(prop_list_i.values())) 
#     color_i = system_color_map[name_i]

#     if not any([np.isnan(i) for i in df_i.elec_energy.tolist()]):


# system_color_map[
   
#     "_".join([
#         str(df_i.iloc[0]["system"]),
#         str(df_i.iloc[0]["spinpol"]),
#         str(df_i.iloc[0]["site"]),
#         str(df_i.iloc[0]["graph_site"]),
#         ])
#     ]

# "_".join([
#     str(df_i.iloc[0]["system"]),
#     str(df_i.iloc[0]["spinpol"]),
# #     str(df_i.iloc[0]["site"]),
#     str(df_i.iloc[0]["graph_site"]),
#     ])

# %% [markdown]
# # an_scaling_new

# %%
# {'ooh': nan, 'o': nan, 'oh': nan}
# system_N_graph | site_C-C bridged | spinpol_False

# {'ooh': nan, 'o': nan, 'oh': nan}
# system_N_graph | site_C-C bridged | spinpol_True

# %%
# for series_i in ORR_PLT.series_list:
#     tmp = 42
#     print(series_i.energy_states_dict)
#     print(series_i.series_name)
#     print("")

# %%
# bias = 0.
# scaling_dict = scaling_dict_ideal

# %%
# import pandas as pd
# import numpy as np
# import plotly.graph_objs as go
# import plotly.plotly as py

#     proj_dir_name,
#     scaling_dict,
#     scaling_dict_ideal,
#     gas_molec_dict,
#     df_vegge,

# %%
# for series_i in ORR_PLT.series_list:
#     energy_ooh = series_i.energy_states_dict["ooh"]
#     energy_o = series_i.energy_states_dict["o"]
    
#     print(energy_ooh)

# %%
# df_o = df_m[df_m["coverage_type"] == "o_covered"]
# df_m_tmp = df_o

# ORR_PLT = ORR_Free_E_Plot(
#     free_energy_df=None,
#     state_title="adsorbate",
#     free_e_title="ads_e",  
#     bias=0.,
#     color_list=None,   
#     show_H_e_pairs_annotations=True,
#     show_legend=True,
#     rxn_type="OER",
#     )



####################################################################################
####################################################################################
####################################################################################
####################################################################################
####################################################################################
####################################################################################
####################################################################################
####################################################################################


# #     df_i = group
# #     df_dict["_".join(list(name))] = df_i
#     # Choosing the most stable *OOH species
#     # ###################################################
#     species_j = "ooh"
#     df_wo_species = df_i[df_i["adsorbate"] != species_j]
#     df_ij = df_i[df_i["adsorbate"] == species_j]
#     df_final = df_wo_species.append(
#         df_ij.loc[df_ij["ads_e"].idxmin()]
#         )
#     df_final

#     df_i = df_final
#     # ###################################################

#     sys_i = df_i.iloc[0]["bulk_system"] + "_" + df_i.iloc[0]["facet"]
#     color_i = system_color_map[sys_i]

#     if not any([np.isnan(i) for i in df_i.elec_energy.tolist()]):        
#         ORR_PLT.add_series(
#             df_i,
#             plot_mode="all",
# #             opt_name=df_i["name_i"].tolist()[0],
#             overpotential_type="OER",
#             property_key_list=prop_name_list,
#             add_overpot=False,
#             color=color_i,
#             )

# %%
# ('Fe_slab', 'trifold', True)
# nan

# system
# site
# spinpol

# %%
# df_m[
#     (df_m["system"] == "Fe_slab") & \
#     (df_m["site"] == "trifold") & \
#     (df_m["spinpol"] == True)
#     ]

# df_m.loc[4].full_path

# list(df_m)

# %%
# smart_format_dict = [

#     [
#         {"author_short": "norskov"},
#         {"symbol": "triangle-up"},
#         ],

#     [
#         {"author_short": "vegge"},
#         # {"symbol": "octagon-open-dot"},
#         {"symbol": "hexagon2"},
#         ],

#     [
#         {"spinpol": True},
#         {"color1": "blue"},
#         ],

#     [
#         {"spinpol": False},
#         {"color1": "orange"},
#         ],
    
#     # [
#     #     {"": ""},
#     #     {"": ""},
#     #     ],
#     # 
#     # [
#     #     {"": ""},
#     #     {"": ""},
#     #     ],
#     ]

# %%
# energy_dict = ORR_PLT.series_list[5].energy_states_dict


# if np.isnan(energy_dict["ooh"]):
#     if not np.isnan(energy_dict["oh"]):

#         ooh_new = 1 * energy_dict["oh"] + 3.2
        
# if np.isnan(energy_dict["o"]):
#     if not np.isnan(energy_dict["oh"]):

#         o_new = 2 * energy_dict["oh"] + 0.

# %%
# # np.nan in list(energy_dict.values())

# # list(energy_dict.values())

# if True in list(np.isnan(list(energy_dict.values()))):
#     print("There is a nan in the energy dict!!!")

#     if np.isnan(energy_dict["ooh"]):
#         if not np.isnan(energy_dict["oh"]):
#             print("*OOH energy set by *OH and standard scaling")
#             ooh_new = 1 * energy_dict["oh"] + 3.2
#             energy_dict["ooh"] = ooh_new
            
#     if np.isnan(energy_dict["o"]):
#         if not np.isnan(energy_dict["oh"]):
#             print("*O energy set by *OH and standard scaling")
#             o_new = 2 * energy_dict["oh"] + 0.
#             energy_dict["o"] = o_new

#     if np.isnan(energy_dict["oh"]):
#         if not np.isnan(energy_dict["ooh"]):
#             print("*OH energy set by *OOH and standard scaling")
#             oh_new = energy_dict["ooh"] - 3.2
#             energy_dict["oh"] = oh_new
